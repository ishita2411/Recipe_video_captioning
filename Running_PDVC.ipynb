# %% [markdown]
# <a href="https://colab.research.google.com/github/avisinghal6/VIDEO_CAPTIONING_PIPELINE/blob/main/Running_PDVC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --recursive https://github.com/avisinghal6/Parallel_Dense_Video_Captioning_Custom.git
# Out:
# Cloning into 'Parallel_Dense_Video_Captioning_Custom'...
# remote: Enumerating objects: 234, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 234 (delta 63), reused 192 (delta 38), pack-reused 0
# Receiving objects: 100% (234/234), 31.08 MiB | 15.54 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# Submodule 'Deformable-DETR' (https://github.com/fundamentalvision/Deformable-DETR.git) registered for path 'Deformable-DETR'
# Submodule 'densevid_eval3/SODA' (https://github.com/fujiso/SODA.git) registered for path 'densevid_eval3/SODA'
# Submodule 'densevid_eval3/pycocoevalcap' (https://github.com/salaniz/pycocoevalcap.git) registered for path 'densevid_eval3/pycocoevalcap'
# Cloning into '/content/Parallel_Dense_Video_Captioning_Custom/Deformable-DETR'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (16/16), done.
# ...

# %%
# %cd /Parallel_Dense_Video_Captioning_Custom
# Out:
# [Errno 2] No such file or directory: '/Parallel_Dense_Video_Captioning_Custom'
# /content/Parallel_Dense_Video_Captioning_Custom/data/yc2/features

# %%
# !pip install -r requirement.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 13.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=fdab88991f15f27fa7fe990d8f34c4bb52fe76e1c1699daf50c74303f529c555
#   Stored in directory: /root/.cache/pip/wheels/1d/57/24/4eff6a03a9ea0e647568e8a5a0546cdf957e3cf005372c0245
# Successfully built ffmpeg
# ...

# %%
# %cd /content/Parallel_Dense_Video_Captioning_Custom/data/yc2/features
# Out:
# /content/Parallel_Dense_Video_Captioning_Custom/data/yc2/features

# %%
# !bash download_yc2_tsn_features.sh
# Out:
# download_yc2_tsn_features.sh: line 1: http://youcook2.eecs.umich.edu/static/dat/yc2_densecap/training_feat_yc2.tar.gz: No such file or directory
# --2023-03-25 03:05:25--  http://youcook2.eecs.umich.edu/static/dat/yc2_densecap/testing_feat_yc2.tar.gz
# Resolving youcook2.eecs.umich.edu (youcook2.eecs.umich.edu)... 141.212.115.67
# Connecting to youcook2.eecs.umich.edu (youcook2.eecs.umich.edu)|141.212.115.67|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1531091112 (1.4G) [application/octet-stream]
# Saving to: ‘testing_feat_yc2.tar.gz’
#
# testing_feat_yc2.ta 100%[===================>]   1.43G  38.0MB/s    in 31s
#
# 2023-03-25 03:05:56 (47.5 MB/s) - ‘testing_feat_yc2.tar.gz’ saved [1531091112/1531091112]
#
# testing/
# testing/qZg0ANIXrLc_resnet.npy
# testing/6a9L8AlCHJU_resnet.npy
# testing/v6P7KH7bxks_resnet.npy
# testing/KHKKNN3uog0_resnet.npy
# testing/wgMqKUqaW_w_resnet.npy
# testing/CLicrRJa-D8_bn.npy
# testing/qaoXYML2DaE_resnet.npy
# ...

# %%
# %cd /content/Parallel_Dense_Video_Captioning_Custom
# Out:
# /content/Parallel_Dense_Video_Captioning_Custom

# %%
# %cd /content/Parallel_Dense_Video_Captioning_Custom/Deformable-DETR/models/ops
# Out:
# /content/Parallel_Dense_Video_Captioning_Custom/Deformable-DETR/models/ops

# %%
# !python setup.py install
# Out:
# running install
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating MultiScaleDeformableAttention.egg-info
# writing MultiScaleDeformableAttention.egg-info/PKG-INFO
# writing dependency_links to MultiScaleDeformableAttention.egg-info/dependency_links.txt
# writing top-level names to MultiScaleDeformableAttention.egg-info/top_level.txt
# writing manifest file 'MultiScaleDeformableAttention.egg-info/SOURCES.txt'
# ...

# %%
#copy the model to the path
video_folder="visualization/videos"
output_folder="visualization/output"
pdvc_model_path="save/model/model-best.pth"
output_language="en"
# !bash test_and_visualize.sh $video_folder $output_folder $pdvc_model_path $output_language
# Out:
# START GENERATE METADATA
# Namespace(video_folder='visualization/videos', ext='txt', output_csv='visualization/videos/metadata.csv', workers=20)
# Number of video files: 1
# WARNING: -rJ5CI0hXHA has an issue. video_fps = None, len(pts) = None.
# Saved metadata to visualization/videos/metadata.csv
# mkdir: missing operand
# Try 'mkdir --help' for more information.
# START Dense-Captioning
# {'eval_save_dir': 'visualization/output', 'eval_mode': 'test', 'test_video_feature_folder': ['visualization/output/r2plus1d_34-tsp_on_activitynet_stride_16/'], 'test_video_meta_data_csv_path': 'visualization/videos/metadata.csv', 'eval_folder': 'generated_captions', 'eval_model_path': 'save/model/model-best.pth', 'eval_tool_version': '2018', 'eval_caption_file': 'data/anet/captiondata/val_1.json', 'eval_proposal_type': 'gt', 'eval_transformer_input_type': 'queries', 'gpu_id': ['0'], 'eval_device': 'cuda'}
# load info from save/model/info.json
# load translator, total_vocab: %d 5747
# ...

# %%
# config_path="cfgs/yc2_tsn_pdvc.yml"
# !python train.py --cfg_path $config_path --gpu_id 0
# Out:
# args.id: yc2_tsn_pdvc
# Rename opt.id as "yc2_tsn_pdvc_v_2023-03-25-02-37-19".
# Results folder "save/yc2_tsn_pdvc_v_2023-03-25-02-37-19" does not exist, creating folder...
# backup evironment completed !
# load translator, total_vocab: %d 5747
# load captioning file, %d captioning loaded 1333
# load translator, total_vocab: %d 5747
# load captioning file, %d captioning loaded 457
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...
